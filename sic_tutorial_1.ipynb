# %%
# Out:
# So luong quan an:  1000

# %%
import requests
import json


def get_home_collections(latitude=10.77253621500006, longitude=106.69798153800008):
    url = "https://gw.be.com.vn/api/v1/be-merchant-gateway/web/customer/get_home_collections"

    payload = json.dumps({
    "latitude":latitude ,
    "longitude":longitude,
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTMyNTAyOCwiaWF0IjoxNzQ1MjM4NjI4LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.R3OCgrjzH1QFhvx0UbwC6WMeJOgQ9039_Qg4rUw4cPo',
    'content-type': 'application/json',
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return json.loads(response.text)


def get_restaurants(collection_id=232, page=1, limit=100, latitude=10, longitude=106):
    url = "https://gw.be.com.vn/api/v1/be-marketplace/web/collection/items/restaurants"

    payload = json.dumps({
    "collection_id": f"{collection_id}",
    "page": page,
    "limit": limit,
    "latitude": latitude,
    "longitude": longitude
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTMyNTAyOCwiaWF0IjoxNzQ1MjM4NjI4LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.R3OCgrjzH1QFhvx0UbwC6WMeJOgQ9039_Qg4rUw4cPo',
    'content-type': 'application/json',
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    json_object_data = json.loads(response.text)
    return json_object_data


def get_detail(restaurant_id=8186, latitude=10, longitude=106):
    url = "https://gw.be.com.vn/api/v1/be-marketplace/web/restaurant/detail"

    payload = json.dumps({
    "restaurant_id": f"{restaurant_id}",
    "latitude": latitude,
    "longitude": longitude,
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTMyNTAyOCwiaWF0IjoxNzQ1MjM4NjI4LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.R3OCgrjzH1QFhvx0UbwC6WMeJOgQ9039_Qg4rUw4cPo',
    'content-type': 'application/json',
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    return json.loads(response.text)

# %%
latitude=10.77253621500006
longitude=106.69798153800008

# Lấy collection ids
collection_ids = get_home_collections(latitude=latitude, longitude=longitude)

for data_ids in collection_ids['collections']:
    print(f"======= START CRAWLER ID: {data_ids['id']} --- Name: {data_ids['name']} =======")
    # code here
    for page_id in range(1,1001):
        restaurants_data = get_restaurants(collection_id=data_ids['id'], page=page_id, limit=100, latitude=latitude, longitude=longitude)
        for restaurant in restaurants_data['data']:
            print("Name: ", restaurant['name'])
            print("Address: ", restaurant['address'])
            print("restaurant_id: ", restaurant['restaurant_id'])
            detail_restaurant = get_detail(restaurant_id=restaurant['restaurant_id'], latitude=latitude, longitude=longitude)
            print(detail_restaurant)
            for i, detail in enumerate(detail_restaurant['data']['categories']):
                print("Mon so: ", i+1)
                print("Ten Mon: ", detail['category_name'])
                for item in detail['items']:
                    print("Item Name: ", item['item_name'], ", item price: ", item['display_price'])
                break
            break
        break
    print(f"======= END CRAWLER ID: {data_ids['id']} --- Name: {data_ids['name']} =======")
    print()
#lưu vào file
with open('be_data.json', 'w') as outfile:
    json.dump(collection_ids, outfile, indent=4)
with open('be_restaurants.json', 'w') as outfile:
    json.dump(restaurants_data, outfile, indent=4)
# Out:
# ======= START CRAWLER ID: 763 --- Name: Bún Phở =======
# Name:  Bún Thịt Nướng Xuân Mai - Bún Mắm & Ăn Vặt - Chợ Bến Thành
# Address:  Sạp 1066/1090 Chợ Bến Thành, Lê Lợi, P. Bến Thành, Quận 1, TP. HCM
# restaurant_id:  22752
# ...
